# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the synthetic dataset
df = pd.read_csv(r"../data/leads.csv")
df.head()
# Out:
#    lead_id       source  recency_days  region                  role  \
# 0        1      Webinar            85     SEA  Working Professional
# 1        2     Referral            42   India  Working Professional
# 2        3      Organic            74  Europe               Student
# 3        4      Organic            13   India  Working Professional
# 4        5  LinkedIn Ad            16   India               Manager
#
#             campaign  page_views           last_touch  prior_course_interest  \
# 0     AI_Course_2025          35        Website Visit                      1
# 1  DataScience_Offer          90        Website Visit                      0
# 2  Summer_Internship          41      Emailed Support                      1
# 3  Summer_Internship          17     Attended Webinar                      0
# 4  DataScience_Offer          99  Downloaded Brochure                      1
#
#   heat_label
# 0       Warm
# 1       Warm
# 2       Warm
# 3       Cold
# 4       Warm

# %%
print("\n🔹 Info:\n")
df.info()
# Out:
# 🔹 Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   lead_id                2000 non-null   int64
#  1   source                 2000 non-null   object
#  2   recency_days           2000 non-null   int64
#  3   region                 2000 non-null   object
#  4   role                   2000 non-null   object
#  5   campaign               2000 non-null   object
#  6   page_views             2000 non-null   int64
#  7   last_touch             2000 non-null   object
#  8   prior_course_interest  2000 non-null   int64
#  9   heat_label             2000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 156.4+ KB

# %%
print("\n🔹 Summary statistics:\n")
df.describe(include="all")
# Out:
# 🔹 Summary statistics:
#             lead_id   source  recency_days  region     role  \
# count   2000.000000     2000    2000.00000    2000     2000
# unique          NaN        5           NaN       4        4
# top             NaN  Organic           NaN  Europe  Student
# freq            NaN      422           NaN     526      512
# mean    1000.500000      NaN      45.52500     NaN      NaN
# std      577.494589      NaN      26.70054     NaN      NaN
# min        1.000000      NaN       0.00000     NaN      NaN
# 25%      500.750000      NaN      22.00000     NaN      NaN
# 50%     1000.500000      NaN      46.00000     NaN      NaN
# 75%     1500.250000      NaN      69.00000     NaN      NaN
# max     2000.000000      NaN      90.00000     NaN      NaN
#
#                  campaign   page_views       last_touch  \
# count                2000  2000.000000             2000
# unique                  3          NaN                4
# ...

# %%
print("\n🔹 Missing values:\n", df.isnull().sum())
# Out:
# 🔹 Missing values:
#  lead_id                  0
# source                   0
# recency_days             0
# region                   0
# role                     0
# campaign                 0
# page_views               0
# last_touch               0
# prior_course_interest    0
# heat_label               0
# dtype: int64

# %%
print("\n🔹 Value counts of heat_label:\n", df["heat_label"].value_counts())
# Out:
# 🔹 Value counts of heat_label:
#  heat_label
# Warm    1211
# Cold     599
# Hot      190
# Name: count, dtype: int64

# %%
df["heat_label"].value_counts().plot(kind="bar", title="Heat Label Distribution")
plt.show()
